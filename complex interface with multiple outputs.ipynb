# %%
# Aim: To demonstrate a complex interface with multiple outputs

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# %matplotlib inline

num_points = 100
v = 10
df = pd.DataFrame(np.random.multivariate_normal([0,0,0,0],[[v,0,0,0],[0,v,0,0],[0,0,v,0], [0,0,0,v]], num_points), columns=['x1', 'x2', 'x3', 'e'])
                                                 
df['y'] = 5 + 2*df['x1'] - 0.5*df['x2'] + df['x3'] + df['e']

# %%
from pandas.tools.plotting import scatter_matrix


import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="white")



g = sns.PairGrid(df, diag_sharey=False)
g.map_lower(sns.kdeplot, cmap="Blues_d")
g.map_upper(plt.scatter)
g.map_diag(sns.kdeplot, lw=3)

# %%
from IPython.display import Javascript, display, clear_output
from ipywidgets import IntSlider, FloatSlider, Layout, HBox, interact

# %%
??interact

# %%
num_points = 100
pd.DataFrame(np.random.multivariate_normal([0,0,0],[[1,0,0],[0,1,0],[0,0,1]], num_points), columns=['x1', 'x2', 'e'])
# Out:
#           x1        x2         e
# 0   1.460976 -2.505395 -0.202603
# 1  -0.201571 -2.013792 -1.574696
# 2   1.338279 -0.648223  0.350402
# 3   1.025488 -0.135195 -0.605932
# 4  -0.352419  0.528237  1.998370
# 5   0.964403 -0.966285 -2.098392
# 6   0.116290 -0.592265  0.635158
# 7  -0.477382 -0.912297 -0.771187
# 8  -0.108125 -0.249390 -0.255327
# 9   0.754761  2.017040  0.828376
# 10 -0.468838 -1.214255  0.096837
# 11 -0.118961  0.090734 -2.806464
# 12  0.289413 -0.136951  0.041762
# 13 -0.383803 -1.559032  0.024226
# 14  0.090598  1.210660  0.351297
# 15  0.219208  1.516718  0.536547
# 16 -1.453428 -0.356484 -0.087154
# 17 -1.503803  1.827504  0.946408
# 18 -0.165000  1.008929 -0.742148
# 19  0.748329  0.325829 -1.541726
# 20  0.684816  0.278686 -1.353538
# 21 -0.890091 -1.144864 -0.670818
# 22  0.222752  0.781429  0.638627
# 23  0.297034 -0.845929  0.579419
# 24 -1.432618 -0.054814  0.253715
# 25  1.590213 -0.507865 -1.249323
# 26 -0.456128 -1.440632  2.456281
# ...
